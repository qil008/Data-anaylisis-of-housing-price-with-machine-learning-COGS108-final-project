# %% [markdown]
# # COGS 108 - Model evaluation and EDA on housing price dataset from California and Boston

# %% [markdown]
# # Link for video:
# https://drive.google.com/drive/folders/1cp_9lU0Qhi5RoJ_nY9YoISfugdXvJyp9?usp=sharing

# %% [markdown]
# # Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [ x ] YES - make available
# * [  ] NO - keep private

# %% [markdown]
# # Names
# - Alyssa Sierra
# - Xavier Ramirez
# - Yeogyeong Choi
# - Yijie Ding
# - Qianjun Li

# %% [markdown]
# # Abstract
#
# Our group found a lot of available data on housing data, and thought of our natural assumptions of what results the data would show: specifically that being closer to the ocean would drive the prices of homes up. We also wanted to explore and use different prediction models. Additionally, we noticed that the California and Boston housing datasets we chose had characteristic differences in the amount of data points we had and the number of features that determine the final housing price (basically, one had a low of rows and one had more columns). We jumped on this opportunity to learn about how this kind of difference would affect performance of some machine learning models.
#
# Due to the nature of our experiment, we worked on two different datasets fairly separately. For the California housing data, we looked most keenly at three factors during our Exploratory Data Analysis: ocean proximity (what we predicted to be the greatest influencing factor), median income, and longitude/latitide data. We found that the ocean proximity data, as it came in the dataset, made it a bit hard to visually confirm the correlation we computed, but our coordinate data more clearly revealed that the highest median house values are clustered near the coast. Median income also had a very clear and strong correlation when graphed against median housing value. As for the Boston dataset, after cleaning, we looked primarily and highway accessability and adjacency to the Charles River as variables to compare to median home values. We saw both a fairly weak inverse relationship and a weak positive relationship between each variable respectively.
#
# After applying Linear Regression, Random Forest, and Neural Network models to each dataset, we discovered the the Random Forest ensemble models performed the best at predicting both median house value in the California Housing data set, as well as median home value in the Boston Housing data. However, the R-value obtained from the model testing was significantly lower for the California data compared to the Boston data.
#
# Our observations reflect an ensemble model's great ability to handle the intricate interactions between both numerical and categorical features, and discern greater correlations between them. We also observed the California dataset, with it's large amount of observations as compared to the Boston dataset, leads to greater variablility in features and thus greater error in our predictions.

# %% [markdown]
# # Research Question

# %% [markdown]
# How well (best accuracy) can we model housing prices given relevant geological and statistical info(specified in data section)?
#  - Which model among linear regressor, ensemble, and neural network gives best accuracy?
#  - Considering dataset characteristics, how does the nature of the dataset - one with a greater number of observations but fewer features (as seen in the California housing dataset) versus one with fewer observations but a richer set of features (as in the Boston housing dataset) - influence the robustness of the model?
#  - What is the most influencial feature in each of the two data set?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Housing price prediction remains a key focus in data science, especially in dynamic and complex real estate markets such as those in California and Boston. These regions, known for their diverse geographies, economic factors, and differing urban characteristics, offer a rich context for applying and testing machine learning algorithms.
#
# In our project, we aim to delve deeper into datasets from both California and Boston. Our primary objective is to compare the performance of various predictive models to determine which one yields the highest accuracy in forecasting housing prices in these two distinct areas. This comparison will involve assessing different machine learning algorithms to identify the most effective model for each specific dataset.
#
# Another crucial aspect of our analysis involves addressing the diversity and complexity of the variables in both the California and Boston datasets. These datasets present us with a unique opportunity to explore how different types of data can influence model performance. The California dataset, with its larger number of observations but fewer features, contrasts with the Boston dataset, which has fewer observations but a richer set of features. By exploring multiple data transformation and normalization techniques, we aim to understand which dataset characteristics — whether it's the quantity of data or the depth of features — most significantly enhance model accuracy.
#
# We found two studies on Kaggle that assist us most in our project, these two project use a similar data set as California housing data.
#
# Here are things we consider crucial in the study of HARRY WANG <a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1):
#
# - Data Cleaning and Transformation: The study underscored the importance of data cleaning and transformation. Transformations like normalization and encoding categorical variables are crucial, allowing us to work with a consistent and comparable dataset, which is essential for effective machine learning models.
#
# - Train Test Split and Validation: Splitting the data into training and test sets and employing validation techniques are key steps. This approach allows us to evaluate our model's performance and generalizability accurately, ensuring it performs well on both the training data and unseen data, thus avoiding overfitting.
#
# - Hyperparameter Tuning: Hyperparameter tuning emerged as a critical aspect. Adjusting these parameters can significantly improve a model's accuracy, making it an essential part of optimizing our predictive models.
#
# - Potential Use of Transformer Models: We are intrigued by the potential of transformer models in housing price prediction. Their ability to handle complex data relationships and sequential information suggests they could uncover deeper insights in real estate data, a possibility we are keen to explore in future checkpoints.
#
# Here are things we consider crucial in the study of MOHAMED KHALED ELSAFTY <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2):
#
# - In the exploratory data analysis (EDA) section of the study, our group found crucial insights into the dynamics of the California housing market. EDA is essential for us, as it helps in uncovering significant patterns and relationships, especially through correlation analysis. This understanding is key in identifying the primary factors impacting housing prices, which in turn informs our model selection and feature engineering strategies.
#
# - Regarding the modeling aspect, the study's detailed examination of linear regression provides a valuable guide for our linear regression model. As beginners in machine learning, learning from this study's approach to implementing and evaluating linear regression is useful. It establishes a baseline model for us, allowing us to effectively compare its performance with more complex models.
#
# Here are things we consider crucial in the study of SAMRAT PANDIRI <a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3):
#
# - The study emphasizes the significance of selecting an appropriate performance metric, such as the coefficient of determination (R2), to quantify model performance. R2 is particularly useful in regression as it describes the proportion of variance in the dependent variable that is predictable from the independent variables.
#
# - Analyzing learning curves is vital in understanding how a model responds as more training data is added. This analysis helps in identifying issues of underfitting or overfitting. The study demonstrates how learning curves provide insights into the model's performance, indicating whether adding more data would be beneficial or if adjustments in model complexity are needed.
#
# - The study highlights the importance of understanding the bias-variance tradeoff through complexity curves. This concept is crucial for our project as it will help us in choosing the right level of model complexity. A model with too little complexity (high bias) won’t capture the nuances of the data, while too much complexity (high variance) leads to overfitting.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) 2018 Housing Price Prediction https://www.kaggle.com/code/harrywang/housing-price-prediction
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) 2022 California Housing (EDA + linear regression) https://www.kaggle.com/code/mohamedkhaledelsafty/california-housing-eda-linear-regression
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) 2018 Boston Housing Prices - Evaluation & Validation https://www.kaggle.com/code/samratp/boston-housing-prices-evaluation-validation

# %% [markdown]
# # Hypothesis

# %% [markdown]
# - We hypothesize that, among the models we are evaluating – linear regressor, neuro network, and ensemble models – one will demonstrate superior accuracy in predicting California housing prices, achieving at least 70% accuracy. This prediction accuracy will be influenced not only by the model's complexity but also by the effectiveness of data transformation and normalization techniques we apply.
# - Our hypothesis further posits that the California housing dataset will outperform the Boston dataset across all three models we are evaluating. We base this assumption on the extensive volume of data available in the California dataset, which consists of approximately 20,000 observations, in stark contrast to Boston's 500. We believe that this greater volume of data will provide a more comprehensive learning opportunity for each model, allowing for more nuanced pattern recognition and, consequently, higher predictive accuracy.
# - Ocean proximity is the most contributing factor to housing price in California housing dataset and distance to employment center is the most contributing factor in Boston dataset.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data overview
#
#
# - Dataset #1
#   - Dataset Name: California Housing Data
#   - Link to the dataset: https://github.com/ageron/handson-ml/blob/master/datasets/housing/housing.csv
#   - Number of observations: 20640
#   - Number of variables: 10
# - Dataset #2
#   - Dataset Name: The Boston Housing Dataset
#   - Link to the dataset: https://www.kaggle.com/code/prasadperera/the-boston-housing-dataset
#   - Number of observations: 506
#   - Number of variables: 14
#
# The California housing dataset, originating from the 1997 paper "Sparse Spatial Autoregressions" by Pace, R. Kelley, and Ronald Barry, is constructed using data from the 1990 California census. It comprises detailed information from each census block group, the smallest geographical unit used by the U.S. Census Bureau, typically encompassing 600 to 3,000 people. With a focus on 20,640 observations across California, the dataset includes a blend of geographical, demographic, and housing-related variables, each reflecting a unique aspect of the housing market:
#
# - Longitude: Indicates how far west a house is located, with higher values signifying a location further west.
# - Latitude: Represents how far north a house is, with higher values indicating a more northern location.
# - Housing Median Age: The median age of a house within a block, where a lower number signifies a newer building.
# - Total Rooms: Total number of rooms within a block.
# - Total Bedrooms: Total number of bedrooms within a block.
# - Population: The total number of people residing within a block.
# - Households: The total number of households, defined as groups of people residing within a home unit, for a block.
# - Median Income: The median income for households within a block, measured in tens of thousands of US Dollars.
# - Ocean Proximity: A categorical variable indicating the proximity to the ocean,  with categories including "&lt;1H OCEAN", "INLAND", "NEAR OCEAN", "NEAR BAY", and "ISLAND".
# - Median House Value: The median house value for households within a block, measured in US Dollars.
#
# The Boston housing dataset, derived from the Boston Standard Metropolitan Statistical Area (SMSA) in 1970, provides a detailed snapshot of various suburbs and towns within the area. Each record in the database is characterized by a set of attributes that capture different aspects of the housing and social environment:
#
# - CRIM: Per capita crime rate by town.
# - ZN: Proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS: Proportion of non-retail business acres per town.
# - CHAS: Charles River dummy variable (1 if tract bounds river; 0 otherwise).
# - NOX: Nitric oxides concentration (parts per 10 million).
# - RM: Average number of rooms per dwelling.
# - AGE: Proportion of owner-occupied units built prior to 1940.
# - DIS: Weighted distances to five Boston employment centers.
# - RAD: Index of accessibility to radial highways.
# - TAX: Full-value property-tax rate per \$10,000.
# - PTRATIO: Pupil-teacher ratio by town.
# - B: 1000(Bk - 0.63)^2, where Bk is the proportion of Black residents by town.
# - LSTAT: Percentage of lower status of the population.
# - MEDV: Median value of owner-occupied homes in \$1000's.
#
# In our project, we are not combining the California and Boston housing datasets, but rather comparing them to understand how different datasets influence the performance of predictive models. Here's how we plan to approach this comparison:
#
# - Model Application: We will apply the same set of models – linear regressor, neural network, and ensemble models – to both datasets independently. This approach allows for a direct comparison of model performance.
#
# - Performance Evaluation: Each model’s predictive accuracy will be evaluated using suitable performance metrics, such as R2 score, mean squared error, or mean absolute error, to assess which dataset enables more effective model performance.
#
# - Feature Analysis: We will analyze how different features in each dataset influence model predictions, including assessing feature importance in models like ensemble models where applicable.
#
# - Data Preprocessing and Transformation: Given the differences in variable units and meanings between the two datasets, the data preprocessing and transformation steps might differ. For instance, while both datasets may require normalization, the approach and extent of normalization might vary. Similarly, handling categorical variables like 'ocean_proximity' in the California dataset and 'CHAS' in the Boston dataset will require tailored approaches.
#
# - Comparative Analysis: The results will be analyzed and contrasted, focusing on model performance in terms of accuracy, overfitting, or underfitting in each dataset. This comparison aims to understand whether a larger dataset with fewer features (California) or a smaller dataset with richer features (Boston) results in more accurate and robust models.

# %% [markdown]
# ## California Housing Data

# %% [markdown]
# ### data loading

# %%
import numpy as np
import pandas as pd
url = 'https://github.com/ageron/handson-ml/blob/master/datasets/housing/housing.csv?raw=true'
CA_df = pd.read_csv(url)
CA_df.shape
# Out:
# (20640, 10)

# %%
CA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
CA_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ### missing value check

# %%
CA_df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
CA_df = CA_df.dropna()
CA_df.shape
# Out:
# (20433, 10)

# %% [markdown]
# ### duplicate value check

# %%
CA_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### handle string variable "ocean_proximity"

# %%
CA_df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# remove rows that are ISLAND, these are outliers that should be excluded.

# %%
CA_df = CA_df[CA_df['ocean_proximity'] != 'ISLAND']

# %% [markdown]
# convert the remaining to numbers

# %% [markdown]
# we are will encode according to distance to ocean for EDA

# %%
proximity_mapping = {
    '<1H OCEAN': 0,
    'NEAR OCEAN': 1,
    'NEAR BAY': 2,
    'INLAND': 3
}

CA_df['ocean_proximity'] = CA_df['ocean_proximity'].map(proximity_mapping)
# Out:
# <ipython-input-9-26d767143fdb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CA_df['ocean_proximity'] = CA_df['ocean_proximity'].map(proximity_mapping)

# %%
CA_df['ocean_proximity'].value_counts()
# Out:
# 0    9034
# 3    6496
# 1    2628
# 2    2270
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# ### outliers check

# %%
import seaborn as sns
import matplotlib.pyplot as plt

num_columns = len(CA_df.columns)
num_rows = int(np.ceil(num_columns / 2))
fig, axs = plt.subplots(num_rows, 2, figsize=(12, num_rows * 1.5))
axs = axs.flatten()

for i, column in enumerate(CA_df.columns):
    sns.boxplot(x=CA_df[column], ax=axs[i])
    axs[i].set_title(column)

if num_columns % 2:
    axs[-1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# We can see that most features have a lot of data falling outside the interquartile range (IQR), we will only keep data with in 2.5 std.

# %%
from scipy import stats
columns =['total_rooms', 'total_bedrooms', 'population',
          'households', 'median_income']
for column in columns:
    CA_df = CA_df[np.abs(stats.zscore(CA_df[column])) < 2.5]

# %%
CA_df.shape
# Out:
# (18041, 10)

# %%
num_columns = len(CA_df.columns)
num_rows = int(np.ceil(num_columns / 2))
fig, axs = plt.subplots(num_rows, 2, figsize=(12, num_rows * 1.5))
axs = axs.flatten()

for i, column in enumerate(CA_df.columns):
    sns.boxplot(x=CA_df[column], ax=axs[i])
    axs[i].set_title(column)

if num_columns % 2:
    axs[-1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## The Boston Housing Dataset

# %% [markdown]
# ### loading data

# %%
url='https://drive.google.com/file/d/1l6OHbJsGNZtVJZmpFuLLYE7FikxhFCac/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
BO_df = pd.read_csv(url)
BO_df.shape
# Out:
# (506, 14)

# %%
BO_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
BO_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# ### missing value check

# %%
BO_df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# ### duplicate value check

# %%
BO_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### outliers check

# %%
num_columns = len(BO_df.columns)
num_rows = int(np.ceil(num_columns / 2))
fig, axs = plt.subplots(num_rows, 2, figsize=(12, num_rows * 1.5))
axs = axs.flatten()

for i, column in enumerate(BO_df.columns):
    sns.boxplot(x=BO_df[column], ax=axs[i])
    axs[i].set_title(column)

if num_columns % 2:
    axs[-1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# The following columns are considered containing outliers。

# %%
columns = ['CRIM', 'ZN', 'RM', 'DIS','PTRATIO', 'B', 'LSTAT']

# %% [markdown]
# we decide to keep data with in 3 std as a tradeoff between sample size

# %%
for column in columns:
    BO_df = BO_df[np.abs(stats.zscore(BO_df[column])) < 3]

# %%
BO_df.shape
# Out:
# (443, 14)

# %%
num_columns = len(BO_df.columns)
num_rows = int(np.ceil(num_columns / 2))
fig, axs = plt.subplots(num_rows, 2, figsize=(12, num_rows * 1.5))
axs = axs.flatten()

for i, column in enumerate(BO_df.columns):
    sns.boxplot(x=BO_df[column], ax=axs[i])
    axs[i].set_title(column)

if num_columns % 2:
    axs[-1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Results

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### California housing EDA
# This data set has data of location that allow us to incorperate map in to visual analysis.

# %% [markdown]
# #### Location related visual analysis

# %%
# !pip install -q folium
# !pip install -q geoplot
# !pip install -q geopandas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 22.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 46.9 MB/s eta 0:00:00

# %%
import patsy
import folium as fm
from folium import plugins as pg
from folium.plugins import HeatMap as hm
import geoplot as gplt
import geopandas as gpd
import branca

# initialize the map and store it in a m object
m = fm.Map(location = [40, -95],
               zoom_start = 4)

cal_map = fm.Map(location=[37.2783, -119.4179], zoom_start=6, min_zoom=5)
data_frame_map = CA_df[['latitude', 'longitude']]
data_points = [[row['latitude'], row['longitude']] for index, row in data_frame_map.iterrows()]
heat_map = hm(data_points, radius=11).add_to(cal_map)
figure = branca.element.Figure(width=800, height=600)  # Width and height in pixels
figure.add_child(cal_map)
figure
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1wxHN0dcL8pMkym-AAOQcamCZbGsQwazj" alt="Alt text">

# %% [markdown]
# This heatmap domenstrate the distribution of all the housing data points on the map. We see that most crowded points for housing are: Los Angelos, San Hose, San Fransisco, Sacramento and San Diego

# %%
# c is the attribute we'll map onto colors, s is the attribute we'll represent with circle size.
CA_df.plot(kind="scatter", x="longitude", y="latitude",
    s=CA_df['population']/100, label="population",
    c="median_house_value", cmap=plt.get_cmap("jet"),
    colorbar=True, alpha=0.4, figsize=(10,7),
)
plt.legend()
plt.show()

# %% [markdown]
# What is the median housing price distribution look like on california map? Do people tended to gather near the ocean? From the graph, it doesn't seems like population has a strong relationship with the ocrean proximity. However, the housing price seems to have a very strong correlation with the ocean proximity.

# %% [markdown]
# #### Overall correlation

# %% [markdown]
# We will drop longitude and latitude for subseqent analysis and model application

# %%
CA_df = CA_df.drop(['longitude', 'latitude'], axis=1)
CA_df.shape
# Out:
# (18041, 8)

# %%
num_columns = len(CA_df.columns)
num_rows = int(np.ceil(num_columns / 2))

fig, axes = plt.subplots(num_rows, 2, figsize=(12, num_rows * 4))
axes_flat = axes.flatten()

for i, column in enumerate(CA_df.columns):
    sns.histplot(CA_df[column], ax=axes_flat[i], kde=True, stat="density", bins=30)

plt.tight_layout()
plt.show()

# %% [markdown]
# We can see that most most features are close to normally distributed (compared to the second dataset). We will apply log or square root to mitigate the skewness. Also since data vary in scale, normaliztion must be applied, we plan to use min max normalization.

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(CA_df.corr(), annot=True)
plt.show()

# %% [markdown]
# We can see that median income is the most important factor according to correlation. There are several instances of high correlation between features. For example, 'total_bedrooms' has a very high correlation with 'total_rooms' (0.88) and 'households' (0.97). 'total_rooms' and 'population' also have a high correlation (0.76).this can significantly impact the performance and interpretability of linear models. High collinearity amongst predictors can inflate the variance of coefficient estimates, leading to unstable models. We will apply PCA and some regulariztion like L2 to mitigate this effect when applying linear model.

# %% [markdown]
# We will pick the most influencial factor median income for a more close up analysis

# %% [markdown]
# #### Median Income

# %%
from scipy.stats import pearsonr
correlation, p_value = pearsonr(CA_df['median_income'], CA_df['median_house_value'])
print(f"Correlation Coefficient: {correlation}")
# Out:
# Correlation Coefficient: 0.654443034837591

# %%
# Scatter plot with regression line
plt.figure(figsize=(10, 7))
sns.regplot(x='median_income', y='median_house_value', data=CA_df, scatter_kws={'alpha': 0.3},line_kws={"color": "red"})
plt.title('Scatter Plot: Median Income vs Median House Value')
plt.xlabel('Median Income (Tens of Thousands USD)')
plt.ylabel('Median House Value (US Dollars)')
plt.show()

# %% [markdown]
# The regression line plotted on the scatter plot reinforces this positive association, suggesting that median income is a strong predictor of median house value. However, the plot also reveals a heteroscedastic pattern: the variation in house values increases with income. This implies that higher-income areas have a more variable range of house prices. Additionally, the presence of a horizontal line at the higher end of the median house value suggests a possible cap in the housing value data. In modeling terms, linear models would capture the general trend but might struggle with the heteroscedastic nature of the data, potentially leading to inefficiencies in the model.

# %% [markdown]
# #### understanding categorical variable Ocean Proximity

# %%
plt.figure(figsize = (10, 6))
sns.countplot(x = 'ocean_proximity', data=CA_df)
plt.title('Distribution of ocean_proximity')
plt.xlabel('ocean_proximity')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(x = 'ocean_proximity',y='median_house_value', data=CA_df)
plt.title('Distribution of ocean_proximity')
plt.xlabel('ocean_proximity')
plt.ylabel('Count')
plt.show()

# %%
correlation, p_value = pearsonr(CA_df['ocean_proximity'], CA_df['median_house_value'])
print(f"Correlation Coefficient: {correlation}")
# Out:
# Correlation Coefficient: -0.40857728967110063

# %%
plt.figure(figsize=(12, 8))
sns.regplot(x = 'ocean_proximity',y='median_house_value', data=CA_df, scatter_kws={'alpha': 0.3}, line_kws={"color": "red"})
plt.title('Relationship between ocean_proximity and median_house_value')
plt.xlabel('ocean_proximity')
plt.ylabel('median_house_value')
plt.show()

# %% [markdown]
# We can see that ocean proximity, althogh exhibits a notable correlation with 'median_house_value', with a correlation coefficient of approximately -0.409. Suggesting the closer to ocean, the higher the housing price. However, this correlation factor is less than median income from previous section, indicating that our hypothesis is incorrect. Given the numeric meaning and coorelation, we will keep this encoding for model section.

# %% [markdown]
# ### Boston housing EDA

# %% [markdown]
# ##### Overall correlation

# %%
num_columns = len(BO_df.columns)
num_rows = int(np.ceil(num_columns / 2))

fig, axes = plt.subplots(num_rows, 2, figsize=(12, num_rows * 4))
axes_flat = axes.flatten()

for i, column in enumerate(BO_df.columns):
    sns.histplot(BO_df[column], ax=axes_flat[i], kde=True, stat="density", bins=30)

plt.tight_layout()
plt.show()

# %% [markdown]
# We can see that only feature MEDV, RM is normally distributed and LSTA close to normally distributed, this lack of normality might affect linear models more than ensemble or DNN. More over, the scale of data varies, thus in the modeling section, we will adopt a min-max standardization.

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(BO_df.corr(), annot=True)
plt.show()

# %% [markdown]
# We can see that LSTAT and RM are two most signicant factor that affect target variable MEDV, and also we see lots of collinearity, this will also affect linear models more. Thus we will apply PCA for linear model in model section.

# %% [markdown]
# #### Understanding catigorical variable

# %% [markdown]
# ##### RAD: indicate how easy it is to access these highways from a particular area. Higher values indicating greater accessibility.

# %% [markdown]
# Frequency Distribution of RAD \
# Here we will plot a bar chart to visualize the frequency distribution of the RAD variable.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 6))
sns.countplot(x = 'RAD', data=BO_df)
plt.title('Distribution of RAD')
plt.xlabel('RAD')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Relationship with Target Variable (MEDV)\
# Here we will explore the relationship between RAD and the target variable MEDV.

# %%
correlation, p_value = pearsonr(BO_df['RAD'], BO_df['MEDV'])
print(f"Correlation Coefficient: {correlation}")
# Out:
# Correlation Coefficient: -0.28612134643157083

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='RAD', y='MEDV', data=BO_df)
plt.title('Relationship between RAD and MEDV')
plt.xlabel('RAD')
plt.ylabel('MEDV')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.regplot(x='RAD', y='MEDV', data=BO_df, scatter_kws={'alpha': 0.3}, line_kws={"color": "red"})
plt.title('Relationship between RAD and MEDV')
plt.xlabel('RAD')
plt.ylabel('MEDV')
plt.show()

# %% [markdown]
# The correlation coefficient of approximately -0.286 suggests a weak to moderate inverse relationship, The scatterplot aligns with the negative correlation coefficient. Overall, based on these two graphs, there is some evidence of a relationship between 'RAD' and 'MEDV', but is not a strong one.

# %% [markdown]
# ##### CHAS: Charles River dummy variable (1 if tract bounds river; 0 otherwise)

# %% [markdown]
# We will look at value_counts() for CHAS since only 2 categories.

# %%
BO_df['CHAS'].value_counts()
# Out:
# 0    412
# 1     31
# Name: CHAS, dtype: int64

# %%
correlation, p_value = pearsonr(BO_df['CHAS'], BO_df['MEDV'])
print(f"Correlation Coefficient: {correlation}")
# Out:
# Correlation Coefficient: 0.16267742257672035

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='CHAS', y='MEDV', data=BO_df)
plt.title('Relationship between CHAS and MEDV')
plt.xlabel('CHAS')
plt.ylabel('MEDV')
plt.show()

# %% [markdown]
# CHAS shows a positive correlation coefficient of approximately 0.163 with the target variable 'MEDV'. This indicates a weak positive relationship. But we decide to keep this variable in our model feature since it is a binary variable, it could potentially serve as an important categorical variable that captures variance in 'MEDV' not explained by other features in a linear model.

# %% [markdown]
# ## Model evaluation

# %% [markdown]
# We are using two evaluating metrics:
# - Root Mean Square Error: the average magnitude of the errors
# - R-Score(R2): how well the model is capturing the underlying patterns of data

# %% [markdown]
# #### California housing

# %% [markdown]
# ##### preprocessing and importing libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.utils import shuffle

# %%
X = CA_df[['housing_median_age', 'total_rooms', 'total_bedrooms',
           'population', 'households', 'median_income', 'ocean_proximity']]
y =  CA_df['median_house_value']

# %%
X, y = shuffle(X, y, random_state=42)

# %% [markdown]
# ##### linear model

# %% [markdown]
# Informed by Colinearity problem we found in EDA, we will use PCA and standard scaler before apply linear model

# %%
pca_pipeline = Pipeline([
    ('scaling', StandardScaler()),
    ('pca', PCA(n_components=0.95))
])

X_pca = pca_pipeline.fit_transform(X)

# %% [markdown]
# RMSE and R2 score with cross validation, we will use these two metrics for evaluating all following models

# %%
linear_model = LinearRegression()

linear_rmse_scores = cross_val_score(linear_model, X_pca, y, cv=5, scoring='neg_mean_squared_error')
linear_rmse_scores = np.sqrt(-linear_rmse_scores)

linear_r2_scores = cross_val_score(linear_model, X_pca, y, cv=5, scoring='r2')

print("Linear Regression Cross-Validated RMSE Scores:", linear_rmse_scores)
print("Mean RMSE:", linear_rmse_scores.mean())
print("Linear Regression Cross-Validated R-squared Scores:", linear_r2_scores)
print("Mean R-squared:", linear_r2_scores.mean())
# Out:
# Linear Regression Cross-Validated RMSE Scores: [76496.21326133 74686.86431122 77002.77140742 73994.12888252
#  72900.11287809]
# Mean RMSE: 75016.01814811617
# Linear Regression Cross-Validated R-squared Scores: [0.51757929 0.53252466 0.51575353 0.55172315 0.53549072]
# Mean R-squared: 0.5306142706879552

# %% [markdown]
# ##### ensemble

# %%
random_forest_model = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42)

forest_rmse_scores = cross_val_score(random_forest_model, X, y, cv=5, scoring='neg_mean_squared_error')
forest_rmse_scores = np.sqrt(-forest_rmse_scores)

forest_r2_scores = cross_val_score(random_forest_model, X, y, cv=5, scoring='r2')

print("Random Forest Cross-Validated RMSE Scores:", forest_rmse_scores)
print("Mean RMSE:", forest_rmse_scores.mean())
print("Random Forest Cross-Validated R-squared Scores:", forest_r2_scores)
print("Mean R-squared:", forest_r2_scores.mean())
# Out:
# Random Forest Cross-Validated RMSE Scores: [64718.384888   61647.86437803 63655.33472949 63274.54188304
#  61383.25078683]
# Mean RMSE: 62935.87533307781
# Random Forest Cross-Validated R-squared Scores: [0.65469616 0.68150228 0.66907974 0.67219935 0.6706651 ]
# Mean R-squared: 0.6696285248114678

# %% [markdown]
# ##### dense neural network

# %% [markdown]
# building model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import KFold
import numpy as np

def build_model():
    model = Sequential([
        Dense(64, activation='relu', input_shape=(X.shape[1],)),
        Dense(64, activation='relu'),
        Dense(1)
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# cross validation result

# %%
def cross_validate(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits)
    rmse_scores = []
    r2_scores = []

    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        model = build_model()
        model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=0)

        y_pred = model.predict(X_test)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)

        rmse_scores.append(rmse)
        r2_scores.append(r2)

    return rmse_scores, r2_scores

# Applying standard scaler for faster convergence
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

rmse_scores, r2_scores = cross_validate(X_scaled, y.values)

print("Cross-Validated RMSE Scores:", rmse_scores)
print("Mean RMSE:", np.mean(rmse_scores))
print("Cross-Validated R-squared Scores:", r2_scores)
print("Mean R-squared:", np.mean(r2_scores))
# Out:
# ...
# 113/113 [==============================] - 0s 2ms/step
# Cross-Validated RMSE Scores: [67934.74464033174, 65297.85875961474, 66501.7020818868, 65530.40788404354, 64983.77687351667]
# Mean RMSE: 66049.6980478787
# Cross-Validated R-squared Scores: [0.6195216369364276, 0.6426711101420829, 0.6388236771588536, 0.6484091743802265, 0.6308967330428588]
# Mean R-squared: 0.6360644663320898

# %% [markdown]
# Analysis:
#
# - Linear Regression: The mean RMSE was approximately 75016 with a mean R-squared of 0.5306. The high RMSE and moderate R-squared indicate moderate predictive accuracy.
# - Random Forest (Ensemble): The mean RMSE improved significantly to about 62936 with a mean R-squared of 0.6696. This shows a better predictive performance compared to the linear model.
# - Neural Network: The mean RMSE was around 66050 with a mean R-squared of 0.6361, placing its performance between the linear model and random forest.
#
# The presence of high collinearity amongst predictors, as noted previously, likely impacted the linear model's performance, even though PCA and regularization are applied. The ensemble and neural network models inherently handle multicollinearity better, which is reflected in their superior performance.

# %% [markdown]
# #### Boston housing

# %% [markdown]
# ##### preprocessing

# %%
BO_df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
X = BO_df[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE',
           'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y =  BO_df['MEDV']
X, y = shuffle(X, y, random_state=42)

# %% [markdown]
# ##### linear model

# %%
pca_pipeline = Pipeline([
    ('scaling', StandardScaler()),
    ('pca', PCA(n_components=0.95))
])

X_pca = pca_pipeline.fit_transform(X)

linear_model = LinearRegression()

linear_rmse_scores = cross_val_score(linear_model, X_pca, y, cv=5, scoring='neg_mean_squared_error')
linear_rmse_scores = np.sqrt(-linear_rmse_scores)

linear_r2_scores = cross_val_score(linear_model, X_pca, y, cv=5, scoring='r2')

print("Linear Regression Cross-Validated RMSE Scores:", linear_rmse_scores)
print("Mean RMSE:", linear_rmse_scores.mean())
print("Linear Regression Cross-Validated R-squared Scores:", linear_r2_scores)
print("Mean R-squared:", linear_r2_scores.mean())
# Out:
# Linear Regression Cross-Validated RMSE Scores: [4.54599917 5.07434239 4.76058647 4.24396515 4.71245411]
# Mean RMSE: 4.667469457687126
# Linear Regression Cross-Validated R-squared Scores: [0.63558625 0.666032   0.67424603 0.73430522 0.70011771]
# Mean R-squared: 0.6820574430975384

# %% [markdown]
# ##### ensemble

# %%
random_forest_model = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42)

forest_rmse_scores = cross_val_score(random_forest_model, X, y, cv=5, scoring='neg_mean_squared_error')
forest_rmse_scores = np.sqrt(-forest_rmse_scores)

forest_r2_scores = cross_val_score(random_forest_model, X, y, cv=5, scoring='r2')

print("Random Forest Cross-Validated RMSE Scores:", forest_rmse_scores)
print("Mean RMSE:", forest_rmse_scores.mean())
print("Random Forest Cross-Validated R-squared Scores:", forest_r2_scores)
print("Mean R-squared:", forest_r2_scores.mean())
# Out:
# Random Forest Cross-Validated RMSE Scores: [2.93244057 3.23395107 2.96546123 2.74593931 3.13013601]
# Mean RMSE: 3.0015856374709475
# Random Forest Cross-Validated R-squared Scores: [0.84836673 0.86435237 0.87359819 0.88877017 0.86769296]
# Mean R-squared: 0.8685560838931663

# %% [markdown]
# ##### neural network

# %%
def cross_validate(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits)
    rmse_scores = []
    r2_scores = []

    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        model = build_model()
        model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=0)

        y_pred = model.predict(X_test)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)

        rmse_scores.append(rmse)
        r2_scores.append(r2)

    return rmse_scores, r2_scores

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

rmse_scores, r2_scores = cross_validate(X_scaled, y.values)

print("Cross-Validated RMSE Scores:", rmse_scores)
print("Mean RMSE:", np.mean(rmse_scores))
print("Cross-Validated R-squared Scores:", r2_scores)
print("Mean R-squared:", np.mean(r2_scores))
# Out:
# ...
# 3/3 [==============================] - 0s 5ms/step
# Cross-Validated RMSE Scores: [3.3238429730566463, 3.2434200308398453, 4.017119330219452, 3.017370926910681, 3.4763549130107885]
# Mean RMSE: 3.415621634807483
# Cross-Validated R-squared Scores: [0.8051873979147245, 0.8635568578243134, 0.7680479232643315, 0.8656935719462842, 0.8368057823984664]
# Mean R-squared: 0.8278583066696239

# %% [markdown]
# Analysis:
#
# - Linear Regression: Exhibited a mean RMSE of approximately 4.667 and a mean R-squared of 0.6821, indicating relatively high accuracy.
# - Random Forest (Ensemble): Showed the best performance with a mean RMSE of around 3.002 and a mean R-squared of 0.8686.
# - Neural Network: Had a mean RMSE of 3.416 and a mean R-squared of 0.8279, performing better than the linear model but not as well as the random forest.
#
# Despite the presence of collinearity in the Boston dataset, the linear model performed relatively well, possibly due to effective PCA application. However, the ensemble model still outperformed the others.

# %% [markdown]
# #### Comparing results
# ##### California dataset
# | Model             | Mean RMSE | Mean R-Squared |
# |-------------------|-----------|----------------|
# | Linear Regression | 75,016    | 0.5306         |
# | Random Forest     | 62,936    | 0.6696         |
# | Neural Network    | 66,050    | 0.6361         |
#
# ##### Boston dataset
# | Model             | Mean RMSE | Mean R-Squared |
# |-------------------|-----------|----------------|
# | Linear Regression | 4.667     | 0.6821         |
# | Random Forest     | 3.002     | 0.8686         |
# | Neural Network    | 3.416     | 0.8279         |

# %% [markdown]
# #### Insights
# ##### Why ensemble the best?
# - Handling Complex Interactions: Ensemble methods, especially Random Forests, are adept at capturing complex interactions between features without requiring explicit feature engineering. The California and Boston datasets both contain features that likely interact in complex ways to determine housing prices (e.g., location features interacting with socio-economic indicators). Random Forests can automatically detect and leverage these interactions.
# - Handling Different Types of Data: Both datasets contain a mix of categorical and continuous variables. Ensemble methods like Random Forests can inherently handle this mix without needing explicit preprocessing like one-hot encoding for categorical data.
#
# #### Why is RMSE significantly larger in California data set and some discussion about it.
# - The density and distribution of data points in the feature space can significantly affect RMSE. The California dataset, with more observations, might have a wider spread in the feature space, leading to higher variability in house prices and, consequently, larger RMSE values.
# - The California dataset, derived from a much larger area, likely encompasses a more diverse and complex set of housing characteristics than the Boston dataset, which focuses on a more specific region (suburbs of Boston). Greater variability and complexity in the features can lead to larger prediction errors.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# In our project, we utilize data from the 1990 California census and the 1970 Boston Standard Metropolitan Statistical Area, which inherently operate under the principle of informed consent. These datasets are publicly available and anonymized, minimizing concerns over personal data privacy. However, we acknowledge potential biases inherent in these datasets. For instance, census data can be biased towards those who respond, often skewing towards certain demographics, such as White families with higher socioeconomic standing, as noted by Pew Research. This potential response bias might influence the representation of various communities within our data.
#
# Additionally, the Boston dataset includes a variable for the proportion of Black residents by town. While this data can offer valuable insights into demographic patterns, we are conscious of the ethical implications of how this information is used and presented. Our team is committed to avoiding any analysis that could inadvertently perpetuate racial biases or stereotypes. We will strictly use location data to analyze proximity to geographical landmarks and other non-discriminatory factors, without drawing direct correlations between specific communities and housing prices.
#
# To address these ethical concerns, our analysis will:
#
# - Focus on geographical and economic factors while cautiously handling demographic data to avoid reinforcing stereotypes or biases.
# - Employ statistical methods to normalize and balance the data, accounting for potential response biases and uneven data distribution across different regions.
# - Ensure that any interpretations or conclusions drawn from the analysis do not single out specific communities or imply causation that could lead to discriminatory practices.
# - Use location data solely for understanding housing prices in relation to proximity to landmarks and amenities, without identifying specific properties or individuals.
#
# Our project aims to provide a fair and unbiased analysis of housing prices in California and Boston, taking into account a variety of factors while remaining vigilant about the ethical implications of our work. We are committed to continuously evaluating our methods and conclusions to ensure they adhere to ethical standards and do not compromise data privacy or equity.

# %% [markdown]
# #</font> Discusison and Conclusion
#
# #### Conclusion for EDA section:
# We are able to see that our hypothesis for most contributing factor to housing value in both datasets are incorrect, and
# - For California data set the most influencial factor is median income.
#
# - For Boston data set the most influencial factor to housing price is: LSTAT, the Percentage of lower status of the population.
#
# #### Conclusion for model evaluation:
# The hypothesis appears to be partially incorrect. While ensemble and neural network models showed better performance than linear regression for the California dataset, none achieved the hypothesized 70% accuracy in R-squared. Moreover, contrary to the hypothesis, the smaller Boston dataset yielded better model performance across all models. This underscores the importance of data quality, feature relationships, and model suitability over merely the size of the dataset. It also highlights the necessity of applying appropriate data transformation and normalization techniques, especially in the presence of feature collinearity, to improve model performance.
#
# In order to address hypothesis and models not achieving the 70% accuracy in the California dataset, there may exist unexpected factors influencing model performance. To discuss the influence of dataset characteristics, more data does not necessarily guarantee better performance while the richness of features in Boston dataset played a significant role in achieving its accuracy. Meanwhile, our analysis of housing price datasets from California and Boston in the 20th century revealed noteworthy insights to predict real estate values. While our initial hypothesis did not fully align with the achieved results, the significance of our findings lies in their potential contribution to contemporary housing market predictions.
#
# Additionally, while we employed datasets from California and Boston in the 20th century, the methodologies and insights gained from our study are generalizable. They can be applied to housing markets in other regions with similar characteristics, fostering broader applicability. However, the evolving dynamics of the real estate market requires ongoing validation of features.
#
#
# # Team Contributions
#
# Xavier Ramirez:
# - Ethics writeup
# - California Housing Dataset EDA
# - Abstract writeup
#
# Qianjun Li:
# - Model evaluation section
# - Background
#
# Yeogyeong Choi:
# - Califorina Housing Dataset EDA
# - Discussion section
#
# Alyssa Sierra:
# - Boston Housing Dataset EDA
# - Video Introduction section
# - Team expectations
#
# Yijie Ding:
# - Dataset writeup
# - California Housing Dataset EDA (geospatial analysis part)
# - Video EDA section
